# %% [markdown]
# # Data Loading and Preprocessing
#
# Load the training data, normalize dtypes, and identify categorical columns.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().resolve()
if project_root.name == "notebooks":
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from src.config import CFG
from src.preprocessing import get_categorical_columns, info_dataframe, load_training_data, split_dataset

# %%
dataframe = load_training_data(CFG.train_path)
train_data, validation_data, test_data = split_dataset(
    dataframe,
    validation_size=CFG.validation_size,
    test_size=CFG.test_size,
    random_state=CFG.random_state,
    stratify_column=CFG.split_stratify_column,
)
cat_cols = get_categorical_columns(train_data)

print(f"Full data shape: {dataframe.shape}")
print(f"Training shape: {train_data.shape}")
print(f"Validation shape: {validation_data.shape}")
print(f"Test shape: {test_data.shape}")
print(f"Categorical columns: {len(cat_cols)}")
# Out:
# Full data shape: (28800, 60)
# Training shape: (20160, 60)
# Validation shape: (4320, 60)
# Test shape: (4320, 60)
# Categorical columns: 35

# %%
display(info_dataframe(dataframe).head(20))
# Out:
#                  column    dtype  missing  unique
# 0                    ID    int32        0   28800
# 1             dri_score   string        0      12
# 2         psych_disturb   string        0       4
# 3            cyto_score   string        0       8
# 4              diabetes   string        0       4
# 5      hla_match_c_high  float32        0       4
# 6        hla_high_res_8  float32        0       8
# 7            tbi_status   string        0       8
# 8            arrhythmia   string        0       4
# 9         hla_low_res_6  float32        0       6
# 10           graft_type   string        0       2
# 11            vent_hist   string        0       3
# 12          renal_issue   string        0       4
# 13          pulm_severe   string        0       4
# 14     prim_disease_hct   string        0      18
# 15       hla_high_res_6  float32        0       7
# 16           cmv_status   string        0       5
# 17      hla_high_res_10  float32        0       9
# 18  hla_match_dqb1_high  float32        0       4
# 19        tce_imm_match   string        0       9
